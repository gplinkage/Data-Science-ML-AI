# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/DataScienceBootCamp/blob/main/Class%20Notes/Instructor's%20notes/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/spam.tsv'
df = pd.read_csv(path, sep='\t')

# %%
df
# Out:
#      label                                            message  length  punct
# 0      ham  Go until jurong point, crazy.. Available only ...     111      9
# 1      ham                      Ok lar... Joking wif u oni...      29      6
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3      ham  U dun say so early hor... U c already then say...      49      6
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61      2
# ...    ...                                                ...     ...    ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1
#
# [5572 rows x 4 columns]

# %%
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.isna().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
df.tail()
# Out:
#      label                                            message  length  punct
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1

# %%
df['label'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
df['label'].value_counts()/(len(df))
# Out:
# ham     0.865937
# spam    0.134063
# Name: label, dtype: float64

# %%
ham = df[df['label']=='ham']
spam = df[df['label']=='spam']

# %%
ham

# %%
spam

# %%
ham.shape, spam.shape
# Out:
# ((4825, 4), (747, 4))

# %%
ham = ham.sample(spam.shape[0])

# %%
ham.shape, spam.shape
# Out:
# ((747, 4), (747, 4))

# %%
data = ham.append(spam, ignore_index=True)
# Out:
# <ipython-input-21-ea3b8d22737f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = ham.append(spam, ignore_index=True)

# %%
data
# Out:
#      label                                            message  length  punct
# 0      ham  What do you do, my dog ? Must I always wait ti...     138      4
# 1      ham                         Thanx 4 sending me home...      26      3
# 2      ham      Prabha..i'm soryda..realy..frm heart i'm sory      45      8
# 3      ham                      I am late. I will be there at      29      1
# 4      ham                                    Try neva mate!!      15      2
# ...    ...                                                ...     ...    ...
# 1489  spam  Want explicit SEX in 30 secs? Ring 02073162414...      90      3
# 1490  spam  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...     158      5
# 1491  spam  Had your contract mobile 11 Mnths? Latest Moto...     160      8
# 1492  spam  REMINDER FROM O2: To get 2.50 pounds free call...     147      3
# 1493  spam  This is the 2nd time we have tried 2 contact u...     160      8
#
# [1494 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data['message'], data['label'], test_size=0.3, random_state=0, shuffle=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
classifier = Pipeline([("tfidf", TfidfVectorizer()) , \
                       ("classifier", RandomForestClassifier(n_estimators=100))])

# %%
classifier.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier', RandomForestClassifier())])

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred, y_test
# Out:
# (array(['spam', 'spam', 'spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham',
#         'ham', 'spam', 'ham', 'ham', 'spam', 'spam', 'spam', 'spam', 'ham',
#         'spam', 'spam', 'spam', 'ham', 'spam', 'spam', 'ham', 'spam',
#         'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'spam', 'spam', 'spam',
#         'spam', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#         'ham', 'spam', 'spam', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham',
#         'spam', 'spam', 'spam', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham',
#         'ham', 'spam', 'spam', 'ham', 'ham', 'ham', 'spam', 'spam', 'spam',
#         'spam', 'spam', 'ham', 'ham', 'spam', 'spam', 'ham', 'ham', 'ham',
#         'spam', 'ham', 'ham', 'ham', 'ham', 'spam', 'spam', 'ham', 'spam',
#         'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'spam', 'spam', 'ham',
#         'ham', 'ham', 'spam', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham',
#         'ham', 'spam', 'spam', 'spam', 'ham', 'ham', 'ham', 'ham', 'spam',
# ...

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9599109131403119

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[226,   1],
#        [ 17, 205]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.93      1.00      0.96       227
#         spam       1.00      0.92      0.96       222
#
#     accuracy                           0.96       449
#    macro avg       0.96      0.96      0.96       449
# weighted avg       0.96      0.96      0.96       449

# %%
test1 = ['Hello, You are learning natural Language Processing']
test2 = ['Hope you are doing good and learning new things !']
test3 = ['Congratulations, You won a lottery ticket worth $1 Million ! To claim call on 446677']

# %%
print(classifier.predict(test1))
print(classifier.predict(test2))
print(classifier.predict(test3))
# Out:
# ['ham']
# ['ham']
# ['spam']
