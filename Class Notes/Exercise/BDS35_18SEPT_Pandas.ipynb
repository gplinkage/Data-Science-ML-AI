# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/DataScienceBootCamp/blob/main/Class%20Notes/Exercise/BDS35_18SEPT_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('demo_data.xlsx')
df
# Out:
#     Worker   Wage  Education   Age
# 0      1.0  17.54         12  76.0
# 1      2.0  20.93         10  61.0
# 2      3.0  12.94          8  75.0
# 3      4.0  19.34          6  38.0
# 4      5.0  24.12         12  59.0
# ..     ...    ...        ...   ...
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0
#
# [80 rows x 4 columns]

# %%
df.isnull().count()
# Out:
# Worker       80
# Wage         80
# Education    80
# Age          80
# dtype: int64

# %%
df_cleaned= df.dropna()
df_cleaned
# Out:
#     Worker   Wage  Education   Age
# 0      1.0  17.54         12  76.0
# 1      2.0  20.93         10  61.0
# 2      3.0  12.94          8  75.0
# 3      4.0  19.34          6  38.0
# 4      5.0  24.12         12  59.0
# ..     ...    ...        ...   ...
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0
#
# [77 rows x 4 columns]

# %%
df_cleaned.describe()
# Out:
#           Worker       Wage  Education        Age
# count  77.000000  77.000000  77.000000  77.000000
# mean   41.571429  25.136364  14.000000  49.038961
# std    23.012256   7.396915   4.006574  17.247762
# min     1.000000  10.030000   6.000000  18.000000
# 25%    23.000000  19.150000  12.000000  34.000000
# 50%    42.000000  25.070000  14.000000  51.000000
# 75%    61.000000  30.850000  17.000000  64.000000
# max    80.000000  43.440000  22.000000  77.000000

# %%
df_cleaned.head(5)
# Out:
#    Worker   Wage  Education   Age
# 0     1.0  17.54         12  76.0
# 1     2.0  20.93         10  61.0
# 2     3.0  12.94          8  75.0
# 3     4.0  19.34          6  38.0
# 4     5.0  24.12         12  59.0

# %%
df_cleaned.tail(5)
# Out:
#     Worker   Wage  Education   Age
# 75    76.0  25.64         14  74.0
# 76    77.0  38.77         21  41.0
# 77    78.0  21.87         15  75.0
# 78    79.0  27.54         20  46.0
# 79    80.0  23.66         12  49.0

# %%
df_cleaned.mean()
# Out:
# Worker       41.571429
# Wage         25.136364
# Education    14.000000
# Age          49.038961
# dtype: float64

# %%
df_cleaned.median()
# Out:
# Worker       42.00
# Wage         25.07
# Education    14.00
# Age          51.00
# dtype: float64

# %%
df_cleaned.std()
# Out:
# Worker       23.012256
# Wage          7.396915
# Education     4.006574
# Age          17.247762
# dtype: float64

# %%
df_cleaned.columns
# Out:
# Index(['Worker', 'Wage', 'Education', 'Age'], dtype='object')

# %%
df_cleaned.sum()
# Out:
# Worker       3201.0
# Wage         1935.5
# Education    1078.0
# Age          3776.0
# dtype: float64

# %%
df_cleaned.max()
# Out:
# Worker       80.00
# Wage         43.44
# Education    22.00
# Age          77.00
# dtype: float64

# %%
df_cleaned.min()
# Out:
# Worker        1.00
# Wage         10.03
# Education     6.00
# Age          18.00
# dtype: float64

# %%
# find mean salary of people with age above 50

# %%
df_cleaned[df_cleaned['Age']>50]
df_cleaned.mean()
# Out:
# Worker       41.571429
# Wage         25.136364
# Education    14.000000
# Age          49.038961
# dtype: float64

# %%
#rohit
df_cleaned.Wage[df_cleaned['Age']>50].mean()
# Out:
# 26.29948717948718

# %%
#find mean salary of people with age below 20
df_cleaned.Wage[df['Age']<20].mean()
# Out:
# 18.759999999999998

# %%
#find which education category has highest wage

# %%
df_cleaned.Education.value_counts().keys()
# Out:
# Int64Index([12, 16, 8, 15, 18, 10, 17, 14, 20, 13, 9, 21, 6, 22], dtype='int64')

# %%
dictonary_of_mean_wage={}

# for k in df_cleaned.Education.value_counts().keys():
for k in set(df_cleaned.Education):
  dictonary_of_mean_wage[k]=df_cleaned.Wage[df['Education']==k].mean()

print(dictonary_of_mean_wage)

max_key = max(dictonary_of_mean_wage, key=dictonary_of_mean_wage.get)
max_value = dictonary_of_mean_wage[max_key]

max_key

# get the key from dictonary which has highest value
# Out:
# {6: 16.134999999999998, 8: 17.398571428571426, 9: 14.11, 10: 19.378333333333334, 12: 22.64363636363636, 13: 19.302500000000002, 14: 27.10833333333333, 15: 27.24857142857143, 16: 29.03875, 17: 28.680000000000003, 18: 31.545714285714286, 20: 32.54, 21: 35.39666666666667, 22: 34.95}
# 21

# %%
df_cleaned.groupby(['Education']).mean().Wage
# Out:
# Education
# 6     16.135000
# 8     17.398571
# 9     14.110000
# 10    19.378333
# 12    22.643636
# 13    19.302500
# 14    27.108333
# 15    27.248571
# 16    29.038750
# 17    28.680000
# 18    31.545714
# 20    32.540000
# 21    35.396667
# 22    34.950000
# Name: Wage, dtype: float64

# %%
#find education and age for highest and lowest wage

# %%
print(df_cleaned[df_cleaned['Wage']==df_cleaned.Wage.min()])
print("===================================================")
print(df_cleaned[df_cleaned['Wage']==df_cleaned.Wage.max()])
# Out:
#     Worker   Wage  Education   Age
# 56    57.0  10.03          9  22.0
# ...
#     Worker   Wage  Education   Age
# 31    32.0  43.44         20  43.0

# %%
df2= pd.read_excel('Ch1_Q20_V12_Data_File.xlsx')
df2
# Out:
#     Observation    x1     x2     x3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0             1  33.0  371.0  189.0         NaN         NaN         NaN
# 1             2  28.0  752.0    NaN         NaN         NaN         NaN
# 2             3  24.0  673.0  204.0         NaN         NaN         NaN
# 3             4  17.0    NaN  151.0         NaN         NaN         NaN
# 4             5  20.0   66.0  191.0         NaN         NaN         NaN
# ..          ...   ...    ...    ...         ...         ...         ...
# 86           87  18.0  412.0  137.0         NaN         NaN         NaN
# 87           88  28.0  629.0  139.0         NaN         NaN         NaN
# 88           89  22.0  167.0  125.0         NaN         NaN         NaN
# 89           90  35.0  842.0  126.0         NaN         NaN         NaN
# 90           91  38.0  180.0  151.0         NaN         NaN         NaN
#
#                                            Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# ...

# %%
#a. How many observations have x1 values greater than 30?
df2_cleaned = df2.iloc[:, :4]
df2_cleaned

#selected_columns = ['Observation', 'x1', 'x2', 'x3']
#df2_selected = df2[selected_columns]
# Out:
#     Observation    x1     x2     x3
# 0             1  33.0  371.0  189.0
# 1             2  28.0  752.0    NaN
# 2             3  24.0  673.0  204.0
# 3             4  17.0    NaN  151.0
# 4             5  20.0   66.0  191.0
# ..          ...   ...    ...    ...
# 86           87  18.0  412.0  137.0
# 87           88  28.0  629.0  139.0
# 88           89  22.0  167.0  125.0
# 89           90  35.0  842.0  126.0
# 90           91  38.0  180.0  151.0
#
# [91 rows x 4 columns]

# %%
df2_cleaned[df2_cleaned['x1']>30].shape
# Out:
# (17, 4)

# %%
#b. Sort the data by x1 in ascending order. What are the x1, x2, and x3 values of the first observation after the data are sorted?
df2_sorted= df2_cleaned.sort_values('x1')
df2_sorted
#df2_sorted = df2_selected.sort_values(by='x1', ascending= True)
#df2_sorted
# Out:
#     Observation    x1     x2     x3
# 50           51   2.0  335.0  166.0
# 58           59   4.0  257.0  144.0
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 81           82   7.0  430.0  160.0
# ..          ...   ...    ...    ...
# 11           12  39.0   62.0  128.0
# 45           46  41.0   71.0   94.0
# 35           36  43.0  768.0  140.0
# 69           70  57.0  218.0  154.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]

# %%
df2_sorted.iloc[0]
# Out:
# Observation     51.0
# x1               2.0
# x2             335.0
# x3             166.0
# Name: 50, dtype: float64

# %%
#c. Sort the data by x1 in descending order. What are the x1, x2, and x3 values of the first observation after the data are sorted?

df2_sorted3 = df2_cleaned.sort_values(by='x1', ascending = False)
df2_sorted3
# Out:
#     Observation    x1     x2     x3
# 69           70  57.0  218.0  154.0
# 35           36  43.0  768.0  140.0
# 45           46  41.0   71.0   94.0
# 11           12  39.0   62.0  128.0
# 33           34  39.0  173.0  160.0
# ..          ...   ...    ...    ...
# 40           41   6.0  992.0  150.0
# 16           17   6.0  999.0  156.0
# 58           59   4.0  257.0  144.0
# 50           51   2.0  335.0  166.0
# 20           21   NaN  850.0  162.0
#
# [91 rows x 4 columns]

# %%
df2_sorted3.iloc[0]
# Out:
# Observation     70.0
# x1              57.0
# x2             218.0
# x3             154.0
# Name: 69, dtype: float64

# %%
# d. How many missing values are there in x1, x2, and x3?

df2_cleaned.isna().sum()

# missing_x1 = df2_cleaned['x1'].isna().sum()
# missing_x2 = df2_cleaned['x2'].isna().sum()
# missing_x3 = df2_cleaned['x3'].isna().sum()

# print(f"d. The number of missing values in x1 is {missing_x1}, in x2 is {missing_x2}, and in x3 is {missing_x3}.")
# Out:
# Observation    0
# x1             1
# x2             3
# x3             5
# dtype: int64
