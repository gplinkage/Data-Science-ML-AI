# %%
temp_str="Hello World"
print(temp_str[::2])
#string slicing [start:stop:step]
# Out:
# HloWrd

# %%
dir(temp_str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
# Takes 1st character of string to upper case
temp_str = "hello world"
print(temp_str.capitalize())
# Out:
# Hello world

# %%
#Returns a string wehre all charecters are lowercase
temp_str= "HeLLo World"
print(temp_str.casefold())
# Out:
# hello world

# %%
# Increases length of string by adding whatever charecter is mentioned if not by default fills by space
temp_str= "HeLLo WorLd"
print (len(temp_str))
print(temp_str.center(18,"*"))
# Out:
# ***HeLLo WorLd****

# %%
# Returns how many times the substring appears in the given range by default picks full string
temp_str= "HeLLo WorLd, how is it going? Hello world".casefold()
print(temp_str)
print(temp_str.count("Hello"))
print(temp_str.count("hello"))

#how to give range?
# count(value,start,end) #start and end are optional if not given takes full string
print(temp_str.count("hello",2))
print(temp_str.count(" hello"))
print(temp_str.count("hello "))
# Out:
# hello world, how is it going? hello world
# 0
# 2
# 1
# 1
# 2

# %%
# returns True or False on the basis of Suffix passed.
temp_str = "HeLLo WorLD how is it going? Hello all good!"
print(temp_str.endswith("god!"))
print(temp_str.endswith("good!"))
#endwith(value, start, end)
print(temp_str.endswith("o", 0,4))
print(temp_str.endswith("o", 0,5))
# Out:
# False
# True
# False
# True

# %%
# returns lowest index of the substring if found else returns -1
temp_str = "HeLLo WorLD how is it going? Hello all good!"
print(temp_str.find("how"))
# Out:
# 12

# %%
#
temp_str = "Hell my name is {fname}, I am a {position}!"
print(temp_str)
print(temp_str.format(fname = "Gov", position="Data Scientist"))

temp_str2 = "Hell my name is {0}, I am a {1}!"
print(temp_str2)
print(temp_str2.format("Gov", "Data Scientist"))
# Out:
# Hell my name is {fname}, I am a {position}!
# Hell my name is Gov, I am a Data Scientist!
# Hell my name is {0}, I am a {1}!
# Hell my name is Gov, I am a Data Scientist!

# %%
#Functions to practice
# format map
# expandtabs

# %%
# replica of find function but this returns error if nothing found
temp_str = "HeLLo WorLD how is it going? Hello all good!"
print(temp_str.index("how"))
print(temp_str.index("howl"))
# Out:
# 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-862a15091265> in <cell line: 4>()
#       2 temp_str = "HeLLo WorLD how is it going? Hello all good!"
#       3 print(temp_str.index("how"))
# ----> 4 print(temp_str.index("howl"))
#       5
#
# ValueError: substring not found

# %%
#Returns True if only numbers and alphabets are present else return false
temp_str = "HeLLo WorLD how is it going? Hello all good!"
print(temp_str.isalnum())
temp_str5 = "Sdf2345"
print(temp_str5.isalnum())
# Out:
# False
# True

# %%
temp_str ="helloworld"
temp_str1 ="1234565"
temp_str2 = "1234abcd"
print(temp_str.isalpha())
print(temp_str1.isalpha())
print(temp_str2.isalpha())
# Out:
# True
# False
# False

# %%
#Only takes numbers (0-9) otherwise returns false
temp_str="HeLLo WorLD"
print(temp_str.isdecimal())
temp_str1="1234567"
print(temp_str1.isdecimal())
temp_str2=" 1234567 "
print(temp_str2.isdecimal())
unicode_0="\u0030"
print(unicode_0.isdecimal())
# Out:
# False
# True
# False
# True

# %%
# returns true if contains only digits/unicode
temp_str="0123456789"
temp_str1="Hello World"
temp_str2="\u0030"
print(temp_str.isdigit())
print(temp_str1.isdigit())
print(temp_str2.isdigit())
# Out:
# True
# False
# True

# %%
#returns true if only numbrs between 0-9 else returns false
temp_str="\u00b2"
print(temp_str.isdecimal())
print(temp_str.isdigit())
print("Km"+temp_str)
# Out:
# False
# True
# Km²

# %%
#returns true for valid variables/key words
temp_str='Hello World'
print(temp_str.isidentifier())
temp_str2= 'if'
print(temp_str2.isidentifier())
# Out:
# False
# False

# %%
#returns true if all the alphabets are of lower case
temp_str2 ="Hello World"
temp_str3 = 'hello12344'
print(temp_str2.islower())
print(temp_str3.islower())
# Out:
# False
# True

# %%
#returns true if first letter of each work is upper case
temp_str="Hello World"
print(temp_str.istitle())
temp_str1= "Hello world"
print(temp_str1.istitle())
# Out:
# True
# False

# %%
#returns true if all the alphabets are of upper case
temp_str2 ="Hello World"
temp_str3 = 'HELLO12344'
print(temp_str2.isupper())
print(temp_str3.isupper())
# Out:
# False
# True

# %%
#.join: joins the list together
list_temp=["Hello", "World", "How", "Are", "you"]
print("#".join(list_temp))
print(" and ".join(list_temp))
# Out:
# Hello#World#How#Are#you
# Hello and World and How and Are and you

# %%
#returns lower cases
temp_str="Hello World"
print(temp_str.lower())
# Out:
# hello world

# %%
#returns upper cases
temp_str="Hello World"
print(temp_str.upper())
print(temp_str.casefold()) #forces everyting to return lower cases includen charecters in other languages
# Out:
# HELLO WORLD
# hello world

# %%
#removes white space from the left/right side of the text
temp_str="       Hello World      "
print(temp_str.lstrip())
print(temp_str.rstrip())
# Out:
# Hello World
#        Hello World

# %%
#removes spaces on both sides
temp_str="    Hello World         "
print(temp_str.strip())
# Out:
# Hello World

# %%
#partition
temp_str="I could eat apples all day"
print(temp_str.partition("apples"))
print(temp_str.partition("all day"))
print(temp_str.partition("all1"))
# Out:
# ('I could eat ', 'apples', ' all day')
# ('I could eat apples ', 'all day', '')
# ('I could eat apples all day', '', '')

# %%
#replaces the string with input string
temp_str="I could eat apples all day, thats all I can say"
print(temp_str.replace('all', 'not'))
print(temp_str.replace('I', 'You').replace('not', 'all'))
# Out:
# I could eat apples not day, thats not I can say
# You could eat apples all day, thats all You can say

# %%
#splits the string at a given spot, for space splits at every space
temp_str="I could eat apples all day, thats all I can say"
print(temp_str.split())
print(temp_str.split(","))
print(temp_str.split("all"))
# Out:
# ['I', 'could', 'eat', 'apples', 'all', 'day,', 'thats', 'all', 'I', 'can', 'say']
# ['I could eat apples all day', ' thats all I can say']
# ['I could eat apples ', ' day, thats ', ' I can say']

# %%
# returns true if starts with the given string
temp_str="I could eat apples all day, thats all I can say"
print(temp_str.startswith("I"))
print(temp_str.startswith("coluld", 2))
# Out:
# True
# False

# %%
#Swapes cases from upper to lower and vice versa
temp_str= "I could EAT apples all day, THAT'S all I can say"
print(temp_str.swapcase())
# Out:
# i COULD eat APPLES ALL DAY, that's ALL i CAN SAY

# %%
#converts to title
temp_str= "I could EAT apples all day, THAT'S all I can say"
temp_str.title()
# Out:
# "I Could Eat Apples All Day, That'S All I Can Say"

# %%
#Dictionaries
temp_str= {83:80, 83:78}
print(temp_str)
# Out:
# {83: 78}

# %%
temp_str ={"Brand":"Ford", "Model":"Mustang", "Year":1964, "Year":2020}
print(temp_str)
print(temp_str["Year"])
# Out:
# {'Brand': 'Ford', 'Model': 'Mustang', 'Year': 2020}
# 2020

# %%
thisdict=dict(name="John", age=34, country="India")
print(thisdict)
# Out:
# {'name': 'John', 'age': 34, 'country': 'India'}

# %%
#Assci Code value of S is 83 defaultly we replace it with 80 here which is P
temp_dict={83:80}
temp_str="Hello Sam! Can you call Samantha?"
print(temp_str.translate(temp_dict))
# Out:
# Hello Pam! Can you call Pamantha?

# %%
#adds zeros at the begining if input is longer than the lenght of the string
temp_str= "I could EAT apples all day, THAT'S all I can say"
print(len(temp_str))
print(temp_str.zfill(10))
print(temp_str.zfill(50))
# Out:
# 48
# I could EAT apples all day, THAT'S all I can say
# 00I could EAT apples all day, THAT'S all I can say
