# %%
#**Thursday August 10, 2023**
str1='Peppa prefer Python Programing'
len(str1)
print(str1[0:5:])
print(str1[6:12:])
print(str1[13:19:])
print(str1[20::])

for items in str1:
  print(items)
# Out:
# Peppa
# prefer
# Python
# Programing
# P
# e
# p
# p
# a
#
# p
# r
# e
# f
# e
# r
#
# P
# y
# t
# h
# o
# n
#
# P
# r
# o
# g
# r
# a
# m
# i
# n
# g

# %%
str1 = 'DjklsjlDduoiusdFjeljwe'
print(str1[::1])
print(str1[::-1])
# Out:
# djklsjldduoiusdfjeljwe
# ewjlejfdsuiouddljslkjd

# %%
str1= 'Peppa prefer Python Programing'
print(str1[::-1])
str1[-1:-11:-1], str1[-12:-18:-1], str1[-19:-24:-1], str1[-26::-1]
# Out:
# gnimargorP nohtyP referp appeP
# ('gnimargorP', 'nohtyP', 'refer', 'appeP')

# %%
# negative indexing negative slicing
str1 = 'VenkataNarasimhaRajuvaripeta'
print(str1)
print (str1[::-1])
print(str1[-22::-1], str1[-13:-22:-1], str1[-1:-13:-1] )
print(str1[6::-1], str1[15:6:-1], str1[27:15:-1])
# Out:
# VenkataNarasimhaRajuvaripeta
# atepiravujaRahmisaraNatakneV
# atakneV ahmisaraN atepiravujaR
# atakneV ahmisaraN atepiravujaR

# %%
#Positive indexing negative slicing
str1 = 'Peppa prefer Python Programming'
print(str1[::])
print(str1[::-1])
print(str1[5::-1], str1[12:5:-1], str1[18:12:-1], str1[:19:-1])
for items in str1:
  print (items)
# Out:
# Peppa prefer Python Programming
# gnimmargorP nohtyP referp appeP
#  appeP  referp nohtyP gnimmargorP
# P
# e
# p
# p
# a
#
# p
# r
# e
# f
# e
# r
#
# P
# y
# t
# h
# o
# n
#
# P
# r
# o
# g
# r
# a
# m
# m
# i
# n
# g

# %%
#negative indexing positive slicing
str1 = 'SrinivasaRamanujanAiyangar'
str1[-26:-17:1], str1[-17:-9:1], str1[-8::1]
# Out:
# ('Srinivasa', 'Ramanuja', 'Aiyangar')

# %%
str1 = 'VenkataNarasimhaRajuvaripeta'
len(str1)
str1[-28:-21:], str1[-21:-12:], str1[-12::]
# Out:
# ('Venkata', 'Narasimha', 'Rajuvaripeta')

# %%
lst1= ['apple', 'banana', 'cherries', 'dates', 'eggfruit', 'fig', 'honeyfruit', 'icefruit']
print(lst1)
print(type(lst1))
lst1[::]
lst1[0:len(lst1):]
lst1[::-1]
lst1[-1::-1]
lst1[9::-1]
lst1[-9::1]
# Out:
# ['apple', 'banana', 'cherries', 'dates', 'eggfruit', 'fig', 'honeyfruit', 'icefruit']
# <class 'list'>
# ['apple',
#  'banana',
#  'cherries',
#  'dates',
#  'eggfruit',
#  'fig',
#  'honeyfruit',
#  'icefruit']

# %%
lst2 =['Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck']
print(lst2)
print(lst2[::])
print(lst2[0:len(lst1):])
print(lst2[::-1])
print(lst2[-1::-1])
print(lst2[6::-1])
print(lst2[-6::1])

for items in lst1:
  print (items)
# Out:
# ['Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck']
# ['Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck']
# ['Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck']
# ['Truck', 'Train', 'Plane', 'Bycycle', 'Bus', 'Car']
# ['Truck', 'Train', 'Plane', 'Bycycle', 'Bus', 'Car']
# ['Truck', 'Train', 'Plane', 'Bycycle', 'Bus', 'Car']
# ['Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck']
# apple
# banana
# cherries
# dates
# eggfruit
# fig
# honeyfruit
# icefruit

# %%
tpl1 =('Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck')
print(tpl1)
print(tpl1[::])
print(tpl1[0:len(tpl1):])
print(tpl1[::-1])
print(tpl1[-1::-1])
print(tpl1[6::-1])
print(tpl1[-6::1])
# Out:
# ('Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck')
# ('Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck')
# ('Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck')
# ('Truck', 'Train', 'Plane', 'Bycycle', 'Bus', 'Car')
# ('Truck', 'Train', 'Plane', 'Bycycle', 'Bus', 'Car')
# ('Truck', 'Train', 'Plane', 'Bycycle', 'Bus', 'Car')
# ('Car', 'Bus', 'Bycycle', 'Plane', 'Train', 'Truck')
