# %%
# check if a number is divisible by 7 or not
num1=14
if num1%7==0:
  print('This number is divisible by 7')
else:
  print('This number is not divisible by 7')
# Out:
# Number is divisible by 7

# %%
# Write a program to print hello if number is multiple of five or 3 else print bye
num2=15
if num2%3==0 or num2%5==0:
  print('hello')
else:
  print('bye')
# Out:
# hello
# hello

# %%
# user input function
input_message= input("Please enter a number: ")
#print(input_message)
print(type(input_message))
# Out:
# Please enter a number: 105
# <class 'str'>

# %%
#changing the input type
input_message= input("Please enter a number: ")
input_message_int= int(input_message)
print(input_message_int)
input_message_int= float(input_message)
print(input_message_int)
# Out:
# Please enter a number: 88
# 88
# 88.0

# %%
#Write a python program that will check for the following conditions:

#If the light is green – Car is allowed to go
#If the light is yellow – Car has to wait
#If the light is red – Car has to stop
#Other signal – unrecognized signal. Example black, blue, etc…

light= input('What is the traffic light: ').lower()

if light== 'green':
  print ('Car is allowed to go')
elif light =='yellow':
    print ('Car has to wait')
elif light=='red':
      print ('Car has to stop')
else:
        print ('unrecognized signal')
# Out:
# What is the traffic light: Green
# Car is allowed to go

# %%
name=input('Enter your name: ').title()
class1= 'class 5'
subject= 'Math'

mark = float(input('Enter your mark: '))

if mark<0 or mark>100:
  print('Error: mark should be between 0 and 100 only')
elif mark<50:
  print("Sorry "+ name +', you failed your '+class1+" "+ subject)
elif mark>50 and mark<60:
  print("Congratulation! "+ name +', you have got a good grade in ' +class1+" "+ subject)
elif mark>60 and mark<80:
  print("Congratulation! "+ name +', you have got a very goog grade in '+class1+" "+ subject)
elif mark>80 and mark<100:
  print("Congratulation! "+ name +', you have got an outstanding grade in '+class1+" "+ subject)
# Out:
# Enter your name: Nam
# Enter your mark: 52
# Congratulation! Nam, you have got a good grade in class 5 Math

# %%
"""
Write a program to trace your subject mark. Your program should fulfill the following conditions:

If the subject mark is below 0 and above 100, print “error: mark should be between 0 and 100 only”
Students will fail in the subject if their mark is below 50.
Students will pass in the subject if they score 50 and above.
If subject mark is between 50 and 60, grade student as good.
If subject mark is between 60 and 80, grade student as very good.
If subject mark is between 80 and 100, grade student as outstanding.

Make sure to print their mark in every statement to prove that the condition is fulfilled. Moreover, name, class, and section should be also displayed along with the marks.
"""
# Out:
# '\nWrite a program to trace your subject mark. Your program should fulfill the following conditions:\n\nIf the subject mark is below 0 and above 100, print “error: mark should be between 0 and 100 only”\nStudents will fail in the subject if their mark is below 50.\nStudents will pass in the subject if they score 50 and above.\nIf subject mark is between 50 and 60, grade student as good.\nIf subject mark is between 60 and 80, grade student as very good.\nIf subject mark is between 80 and 100, grade student as outstanding.\n\nMake sure to print their mark in every statement to prove that the condition is fulfilled. Moreover, name, class, and section should be also displayed along with the marks.\n'

# %%
# Nested IF
a=400

if (a<500):
  print('if (a<500):')
  if (a<400):
    print(' if (a<400):')
    if (a<300):
      print('if (a<300):')
      if (a<200):
        print('if (a<200):')
        if(a<100):
          print('if(a<100):')
          if (a<50):
            print('if (a<50):')
          else:
            print('else if (a>50)')
        else:
          print('else if (a>100)')
      else:
        print('else if (a>200)')
    else:
      print('else if (a>300)')
  else:
    print('else if (a>400)')
else:
  print('else if (a>500)')
# Out:
# if (a<500):
# else if (a>400)
