# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/DataScienceBootCamp/blob/main/Class%20Notes/Notes/BDS35_10OCT_Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# !pip install apyori

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
dataset
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
dataset.shape
# Out:
# (7501, 20)

# %%
transactions = []
for i in range(0, 7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
#transactions

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %% [markdown]
# ## Visualising the results

# %% [markdown]
# ### Displaying the first results coming directly from the output of the apriori function

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [markdown]
# ### Putting the results well organised into a Pandas DataFrame

# %%
def inspect(results):
    # Extracting information from the Apriori algorithm results

    # Extracting the left-hand side of the rules
    lhs = [tuple(result[2][0][0])[0] for result in results]

    # Extracting the right-hand side of the rules
    rhs = [tuple(result[2][0][1])[0] for result in results]

    # Extracting the support values of the rules
    supports = [result[1] for result in results]

    # Extracting the confidence values of the rules
    confidences = [result[2][0][2] for result in results]

    # Extracting the lift values of the rules
    lifts = [result[2][0][3] for result in results]

    # Combining the extracted information into a list of tuples
    return list(zip(lhs, rhs, supports, confidences, lifts))

resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
# def inspect(results):
#     # Initialize empty lists to store different components of each rule
#     lhs = []  # Left-hand side of the rule
#     rhs = []  # Right-hand side of the rule
#     supports = []  # Support value of the rule
#     confidences = []  # Confidence value of the rule
#     lifts = []  # Lift value of the rule

#     # Iterate through each rule in the 'results'
#     for result in results:
#         # Extract the left-hand side of the rule and convert it to a tuple
#         left_hand_side = tuple(result[2][0][0])[0]
#         lhs.append(left_hand_side)

#         # Extract the right-hand side of the rule and convert it to a tuple
#         right_hand_side = tuple(result[2][0][1])[0]
#         rhs.append(right_hand_side)

#         # Extract the support value of the rule
#         support_value = result[1]
#         supports.append(support_value)

#         # Extract the confidence value of the rule
#         confidence_value = result[2][0][2]
#         confidences.append(confidence_value)

#     # Extract the lift value of the rule
#     lift_value = result[2][0][3]
#     lifts.append(lift_value)

# # Combine the lists into a list of tuples
# return list(zip(lhs, rhs, supports, confidences, lifts))

# %% [markdown]
# ### Displaying the results non sorted

# %%
resultsinDataFrame
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 6           light cream       olive oil  0.003200    0.205128  3.114710
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 8                 pasta          shrimp  0.005066    0.322034  4.506672

# %% [markdown]
# ### Displaying the results sorted by descending lifts

# %%
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 8                 pasta          shrimp  0.005066    0.322034  4.506672
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 6           light cream       olive oil  0.003200    0.205128  3.114710
