# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/DataScienceBootCamp/blob/main/Class%20Notes/Notes/BDS35_01SEP_pandas_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #**Python Pandas DataFrame**#

# %%
lst1 = [12, 23, 34, 45, 56, 67, 78, 90, 110]
df1 = pd.DataFrame(lst1)
print(df1)
print(type(df1))
# Out:
#      0
# 0   12
# 1   23
# 2   34
# 3   45
# 4   56
# 5   67
# 6   78
# 7   90
# 8  110
# <class 'pandas.core.frame.DataFrame'>

# %%
lang =['C', 'C++', 'JAVA', 'Python']
df2 = pd.DataFrame(lang)
print (df2)
# Out:
#         0
# 0       C
# 1     C++
# 2    JAVA
# 3  Python

# %%
rating = [4,3,2,1]
df2[1]= rating
df2
# Out:
#         0  1
# 0       C  4
# 1     C++  3
# 2    JAVA  2
# 3  Python  1

# %%
df2.columns = ['language','ratings']
df2
# Out:
#   language  ratings
# 0        C        4
# 1      C++        3
# 2     JAVA        2
# 3   Python        1

# %%
cars = ['Toyota', 'Audi', 'Honda', 'Suzuki', 'Tesla', 'GMC']
df3= pd.DataFrame (cars)
print(df3)
# Out:
#         0
# 0  Toyota
# 1    Audi
# 2   Honda
# 3  Suzuki
# 4   Tesla
# 5     GMC

# %%
ratings = [1, 2, 3, 4, 5,6]

df3[1] = ratings
df3
# Out:
#         0  1
# 0  Toyota  1
# 1    Audi  2
# 2   Honda  3
# 3  Suzuki  4
# 4   Tesla  5
# 5     GMC  6

# %%
df3.columns = ['Cars','ratings']
df3
# Out:
#      Cars  ratings
# 0  Toyota        1
# 1    Audi        2
# 2   Honda        3
# 3  Suzuki        4
# 4   Tesla        5
# 5     GMC        6

# %%
# Create Dataframe from Dictionary
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
df3 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b'])
df3
# Out:
#       a   b
# row1  1   2
# row2  5  10

# %%
df4 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c'])
df4
# Out:
#       a   b     c
# row1  1   2   NaN
# row2  5  10  20.0

# %%
df5 = pd.DataFrame(data, index=['row1', 'row2'], columns=['a', 'b' ,'c' , 'd'])
df5
# Out:
#       a   b     c   d
# row1  1   2   NaN NaN
# row2  5  10  20.0 NaN

# %%
df6 = pd.DataFrame({'ID':[1,2,3,4], 'Name':['Ramesh','Suresh','Naresh','Sukesh']})
df6
# Out:
#    ID    Name
# 0   1  Ramesh
# 1   2  Suresh
# 2   3  Naresh
# 3   4  Sukesh

# %%
df6['ID'], df6['Name']
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  Name: ID, dtype: int64,
#  0    Ramesh
#  1    Suresh
#  2    Naresh
#  3    Sukesh
#  Name: Name, dtype: object)

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %% [markdown]
# #*Dataframe of Random Numbers with Data Indices*#

# %%
dates = pd.date_range (start = '01-Aug-2023', end ='31-Aug-2023')
dates
# Out:
# DatetimeIndex(['2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-05', '2023-08-06', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10', '2023-08-11', '2023-08-12',
#                '2023-08-13', '2023-08-14', '2023-08-15', '2023-08-16',
#                '2023-08-17', '2023-08-18', '2023-08-19', '2023-08-20',
#                '2023-08-21', '2023-08-22', '2023-08-23', '2023-08-24',
#                '2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('today', periods=7)
dates
# Out:
# DatetimeIndex(['2023-09-02 00:38:10.264927', '2023-09-03 00:38:10.264927',
#                '2023-09-04 00:38:10.264927', '2023-09-05 00:38:10.264927',
#                '2023-09-06 00:38:10.264927', '2023-09-07 00:38:10.264927',
#                '2023-09-08 00:38:10.264927'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.date_range('2023-08-25', periods=7)
dates
# Out:
# DatetimeIndex(['2023-08-25', '2023-08-26', '2023-08-27', '2023-08-28',
#                '2023-08-29', '2023-08-30', '2023-08-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
M = np.random.random((7,7))
M
# Out:
# array([[0.91766296, 0.67872929, 0.4295103 , 0.24508139, 0.36182591,
#         0.00141557, 0.23893122],
#        [0.30264132, 0.71063274, 0.54275678, 0.09352868, 0.13823693,
#         0.78257129, 0.22730367],
#        [0.45239799, 0.20305004, 0.97927912, 0.75837363, 0.58956034,
#         0.10030025, 0.50484981],
#        [0.04976398, 0.80814013, 0.08058077, 0.74714023, 0.31675045,
#         0.55741515, 0.4875985 ],
#        [0.04914509, 0.97142707, 0.32222222, 0.83612173, 0.14538391,
#         0.23505202, 0.21105492],
#        [0.08632068, 0.91940809, 0.22613202, 0.69752929, 0.51577824,
#         0.16649376, 0.4986346 ],
#        [0.29067829, 0.88775916, 0.78852229, 0.82410821, 0.14287705,
#         0.52600054, 0.45549528]])

# %%
df = pd.DataFrame (M, index = dates)
df
# Out:
#                    0         1         2         3         4         5  \
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
#
#                    6
# 2023-08-25  0.238931
# 2023-08-26  0.227304
# 2023-08-27  0.504850
# 2023-08-28  0.487599
# 2023-08-29  0.211055
# 2023-08-30  0.498635
# 2023-08-31  0.455495

# %%
df.columns = ['C1','C2','C3','C4','C5','C6','C7']
df
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
#
#                   C7
# 2023-08-25  0.238931
# 2023-08-26  0.227304
# 2023-08-27  0.504850
# 2023-08-28  0.487599
# 2023-08-29  0.211055
# 2023-08-30  0.498635
# 2023-08-31  0.455495

# %%
df.sort_values(by='C1', ascending=True)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
#
#                   C7
# 2023-08-29  0.211055
# 2023-08-28  0.487599
# 2023-08-30  0.498635
# 2023-08-31  0.455495
# 2023-08-26  0.227304
# 2023-08-27  0.504850
# 2023-08-25  0.238931

# %%
df.sort_values(by='C1', ascending=False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
#
#                   C7
# 2023-08-25  0.238931
# 2023-08-27  0.504850
# 2023-08-26  0.227304
# 2023-08-31  0.455495
# 2023-08-30  0.498635
# 2023-08-28  0.487599
# 2023-08-29  0.211055

# %%
df.sort_values(by='C2', ascending=False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
#
#                   C7
# 2023-08-29  0.211055
# 2023-08-30  0.498635
# 2023-08-31  0.455495
# 2023-08-28  0.487599
# 2023-08-26  0.227304
# 2023-08-25  0.238931
# 2023-08-27  0.504850

# %%
df.sort_index(ascending= True)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
#
#                   C7
# 2023-08-25  0.238931
# 2023-08-26  0.227304
# 2023-08-27  0.504850
# 2023-08-28  0.487599
# 2023-08-29  0.211055
# 2023-08-30  0.498635
# 2023-08-31  0.455495

# %%
df.sort_index(ascending= False)
# Out:
#                   C1        C2        C3        C4        C5        C6  \
# 2023-08-31  0.290678  0.887759  0.788522  0.824108  0.142877  0.526001
# 2023-08-30  0.086321  0.919408  0.226132  0.697529  0.515778  0.166494
# 2023-08-29  0.049145  0.971427  0.322222  0.836122  0.145384  0.235052
# 2023-08-28  0.049764  0.808140  0.080581  0.747140  0.316750  0.557415
# 2023-08-27  0.452398  0.203050  0.979279  0.758374  0.589560  0.100300
# 2023-08-26  0.302641  0.710633  0.542757  0.093529  0.138237  0.782571
# 2023-08-25  0.917663  0.678729  0.429510  0.245081  0.361826  0.001416
#
#                   C7
# 2023-08-31  0.455495
# 2023-08-30  0.498635
# 2023-08-29  0.211055
# 2023-08-28  0.487599
# 2023-08-27  0.504850
# 2023-08-26  0.227304
# 2023-08-25  0.238931

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df1 = pd.DataFrame(dict1)
df1
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
del df1 ['B']
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0
# e  NaN

# %%
df1.drop('e', inplace=True)
df1
# Out:
#      A
# a  1.0
# b  2.0
# c  3.0
# d  4.0

# %%
dict1 = {'A': pd.Series([1,2,3,4], index = ['a','b','c','d']),
         'B': pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
         }
df10 = pd.DataFrame(dict1)
df10
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
df10.drop(['A'], axis=1) # axis=0 => rows,  axis=1 => columns
# Out:
#    B
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
df10
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4
# e  NaN  5

# %%
df10.drop(['A'], axis=1, inplace=True) # axis=0 => rows,  axis=1 => columns
df10
# Out:
#    B
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
df10.drop(['A'], axis=1, inplace=False) # axis=0 => rows,  axis=1 => columns
df10
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4

# %%
df10.drop('e', axis=0, inplace=True) # axis=0 => rows,  axis=1 => columns
df10
# Out:
#      A  B
# a  1.0  1
# b  2.0  2
# c  3.0  3
# d  4.0  4

# %%
col1 = np.linspace(10, 100, 30)
col2 = np.random.randint(10,100,30)
df11 = pd.DataFrame({"C1" : col1 , "C2" :col2})
df11
# Out:
#             C1  C2
# 0    10.000000  90
# 1    13.103448  24
# 2    16.206897  47
# 3    19.310345  76
# 4    22.413793  63
# 5    25.517241  82
# 6    28.620690  30
# 7    31.724138  11
# 8    34.827586  47
# 9    37.931034  63
# 10   41.034483  90
# 11   44.137931  46
# 12   47.241379  81
# 13   50.344828  79
# 14   53.448276  37
# 15   56.551724  51
# 16   59.655172  25
# 17   62.758621  99
# 18   65.862069  63
# 19   68.965517  25
# 20   72.068966  49
# 21   75.172414  29
# 22   78.275862  91
# 23   81.379310  94
# 24   84.482759  18
# 25   87.586207  93
# 26   90.689655  52
# 27   93.793103  36
# 28   96.896552  85
# 29  100.000000  87

# %%
df11 = df11.drop([17,18,19], axis= 0)
df11
# Out:
#             C1  C2
# 0    10.000000  90
# 1    13.103448  24
# 2    16.206897  47
# 3    19.310345  76
# 4    22.413793  63
# 5    25.517241  82
# 6    28.620690  30
# 7    31.724138  11
# 8    34.827586  47
# 9    37.931034  63
# 10   41.034483  90
# 11   44.137931  46
# 12   47.241379  81
# 13   50.344828  79
# 14   53.448276  37
# 15   56.551724  51
# 16   59.655172  25
# 20   72.068966  49
# 21   75.172414  29
# 22   78.275862  91
# 23   81.379310  94
# 24   84.482759  18
# 25   87.586207  93
# 26   90.689655  52
# 27   93.793103  36
# 28   96.896552  85
# 29  100.000000  87

# %%
df11 = df11.drop([16], axis= 0)
df11
# Out:
#             C1  C2
# 0    10.000000  90
# 1    13.103448  24
# 2    16.206897  47
# 3    19.310345  76
# 4    22.413793  63
# 5    25.517241  82
# 6    28.620690  30
# 7    31.724138  11
# 8    34.827586  47
# 9    37.931034  63
# 10   41.034483  90
# 11   44.137931  46
# 12   47.241379  81
# 13   50.344828  79
# 14   53.448276  37
# 15   56.551724  51
# 20   72.068966  49
# 21   75.172414  29
# 22   78.275862  91
# 23   81.379310  94
# 24   84.482759  18
# 25   87.586207  93
# 26   90.689655  52
# 27   93.793103  36
# 28   96.896552  85
# 29  100.000000  87

# %%
df11.drop(df11.index[5], inplace=True)
df11
# Out:
#             C1  C2
# 0    10.000000  90
# 1    13.103448  24
# 2    16.206897  47
# 3    19.310345  76
# 4    22.413793  63
# 6    28.620690  30
# 7    31.724138  11
# 8    34.827586  47
# 9    37.931034  63
# 10   41.034483  90
# 11   44.137931  46
# 12   47.241379  81
# 13   50.344828  79
# 14   53.448276  37
# 15   56.551724  51
# 20   72.068966  49
# 21   75.172414  29
# 22   78.275862  91
# 23   81.379310  94
# 24   84.482759  18
# 25   87.586207  93
# 26   90.689655  52
# 27   93.793103  36
# 28   96.896552  85
# 29  100.000000  87

# %%
df11.iloc[10:15]
# Out:
#            C1  C2
# 11  44.137931  46
# 12  47.241379  81
# 13  50.344828  79
# 14  53.448276  37
# 15  56.551724  51

# %%
df11.iloc[10:15,0]
# Out:
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df11.iloc[10:15, 1]
# Out:
# 11    46
# 12    81
# 13    79
# 14    37
# 15    51
# Name: C2, dtype: int64

# %%
df11.loc[10:15, 'C1']
# Out:
# 10    41.034483
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df11.iloc[10:15, 0]
# Out:
# 11    44.137931
# 12    47.241379
# 13    50.344828
# 14    53.448276
# 15    56.551724
# Name: C1, dtype: float64

# %%
df11.loc[10:,'C1':]
# Out:
#             C1  C2
# 10   41.034483  90
# 11   44.137931  46
# 12   47.241379  81
# 13   50.344828  79
# 14   53.448276  37
# 15   56.551724  51
# 20   72.068966  49
# 21   75.172414  29
# 22   78.275862  91
# 23   81.379310  94
# 24   84.482759  18
# 25   87.586207  93
# 26   90.689655  52
# 27   93.793103  36
# 28   96.896552  85
# 29  100.000000  87

# %%
df11.iloc[10:, 0:]
# Out:
#             C1  C2
# 11   44.137931  46
# 12   47.241379  81
# 13   50.344828  79
# 14   53.448276  37
# 15   56.551724  51
# 20   72.068966  49
# 21   75.172414  29
# 22   78.275862  91
# 23   81.379310  94
# 24   84.482759  18
# 25   87.586207  93
# 26   90.689655  52
# 27   93.793103  36
# 28   96.896552  85
# 29  100.000000  87
