# %%
#Typecasting functions
# change one data type to another data type
#{int(), float(), complex(), bool(),str()}
#{list(), tuple(), set(), dict()}

# %%
int1=1947
print(float(int1))
print(complex(int1))
print(bool(int1))
print(str(int1))
#print(list(int1))
#print(tuple(int1))
#print(set(int1))
#print(dict(int1))
# Out:
# 1947.0
# (1947+0j)
# True
# 1947

# %%
# decimal => bin(), oct(), hex()
for i in range(0,10):
  print('Decimal: ', i)
  print('Binary: ', bin(i))
  print('Octa Decimal: ', oct(i))
  print('Hexa Decimal: ', hex(i))
# Out:
# Decimal:  0
# Binary:  0b0
# Octa Decimal:  0o0
# Hexa Decimal:  0x0
# Decimal:  1
# Binary:  0b1
# Octa Decimal:  0o1
# Hexa Decimal:  0x1
# Decimal:  2
# Binary:  0b10
# Octa Decimal:  0o2
# Hexa Decimal:  0x2
# Decimal:  3
# Binary:  0b11
# Octa Decimal:  0o3
# Hexa Decimal:  0x3
# Decimal:  4
# Binary:  0b100
# Octa Decimal:  0o4
# Hexa Decimal:  0x4
# Decimal:  5
# Binary:  0b101
# Octa Decimal:  0o5
# Hexa Decimal:  0x5
# Decimal:  6
# Binary:  0b110
# Octa Decimal:  0o6
# Hexa Decimal:  0x6
# Decimal:  7
# Binary:  0b111
# Octa Decimal:  0o7
# Hexa Decimal:  0x7
# Decimal:  8
# Binary:  0b1000
# Octa Decimal:  0o10
# Hexa Decimal:  0x8
# Decimal:  9
# Binary:  0b1001
# Octa Decimal:  0o11
# Hexa Decimal:  0x9

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
# ...

# %%
# user define function
# This is a function named 'sum_of_two' that takes two parameters 'a' and 'b'
def sum_of_two(a, b):
    # The 'return' statement calculates the sum of 'a' and 'b' and sends the result back to the caller
    return a + b

# %%
sum_of_two(3,5)
# Out:
# 8

# %%
sum_of_two('Python', ' Programing')
# Out:
# 'Python Programing'
