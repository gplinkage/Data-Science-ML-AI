# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/DataScienceBootCamp/blob/main/Class%20Notes/Notes/BD35_11SEP_EDA%2C_LAMDA_%26_LIST_COMPREHENSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the dataset
path = 'https://raw.githubusercontent.com/gitanuurage/EDA/main/blackFriday_train.csv'
df_train=pd.read_csv(path)
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_train.shape
# Out:
# (550068, 12)

# %%
df_train.size
# Out:
# 6600816

# %%
df_train.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
df_train.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df_train.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df_train.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
for features in df_train.columns:
  print (features)
# Out:
# User_ID
# Product_ID
# Gender
# Age
# Occupation
# City_Category
# Stay_In_Current_City_Years
# Marital_Status
# Product_Category_1
# Product_Category_2
# Product_Category_3
# Purchase

# %%
for features in df_train.columns:
  if df_train[features].isnull().sum()>0:
    print(features)
# Out:
# Product_Category_2
# Product_Category_3

# %%
##  import the test data
path = 'https://raw.githubusercontent.com/gitanuurage/EDA/main/blackFriday_test.csv'
df_test=pd.read_csv(path)
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df_test.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3
# 233594                 NaN                 NaN
# ...

# %%
df_test.shape
# Out:
# (233599, 11)

# %%
df_test.size
# Out:
# 2569589

# %%
df_test.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
df_test.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df_test.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
x = (df_test.size/df_train.size)*100
x
# Out:
# 38.92835370657204

# %%
for features in df_test.columns:
  print(features)
# Out:
# User_ID
# Product_ID
# Gender
# Age
# Occupation
# City_Category
# Stay_In_Current_City_Years
# Marital_Status
# Product_Category_1
# Product_Category_2
# Product_Category_3

# %%
for features in df_test.columns:
  if df_test[features].isnull().sum()>0:
    print(features)
# Out:
# Product_Category_2
# Product_Category_3

# %%
# Merge both train and test data
df=df_train.append(df_test)
df.head()
# Out:
# <ipython-input-52-5ab4dd062b80>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df_train.append(df_test)
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
# ...

# %%
df.size, df.shape, df.columns
# Out:
# (9404004,
#  (783667, 12),
#  Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#         'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#         'Product_Category_2', 'Product_Category_3', 'Purchase'],
#        dtype='object'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.drop(['User_ID'], axis=1, inplace=True)

# %%
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df.Gender
# Out:
# 0         F
# 1         F
# 2         F
# 3         F
# 4         M
#          ..
# 233594    F
# 233595    F
# 233596    F
# 233597    F
# 233598    F
# Name: Gender, Length: 783667, dtype: object

# %%
df['Gender']

# %%
df['Gender'] = pd.get_dummies(df['Gender'], drop_first =1)

df
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00069042       0   0-17          10             A
# 1       P00248942       0   0-17          10             A
# 2       P00087842       0   0-17          10             A
# 3       P00085442       0   0-17          10             A
# 4       P00285442       1    55+          16             C
# ...           ...     ...    ...         ...           ...
# 233594  P00118942       0  26-35          15             B
# 233595  P00254642       0  26-35          15             B
# 233596  P00031842       0  26-35          15             B
# 233597  P00124742       0  46-50           1             C
# 233598  P00316642       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df['Gender'] = df['Gender'].map({'F':0, 'M':1})
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042     NaN  0-17          10             A
# 1  P00248942     NaN  0-17          10             A
# 2  P00087842     NaN  0-17          10             A
# 3  P00085442     NaN  0-17          10             A
# 4  P00285442     NaN   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %% [markdown]
# # Python Lambda Functions #

# %%
 x = lambda a: a + 10
 print (x(10))
# Out:
# 20

# %%
x = lambda a, b: a*b+10
print(x(2, 8))
# Out:
# 26

# %%
x = lambda a, b, c : a*b*c
print(x (3, 6, 9))
# Out:
# 162

# %%
Max = lambda a,b : a if(a>b) else b
print(Max(12, 121))
# Out:
# 121

# %%
result = lambda x,y : f"{x} is smaller than {y}" \
if x < y else (f"{x} is greater than {y}" if x > y \
               else f"{x} is equal to {y}")
#\is for change of line

print(result(12, 11))
print(result(12, 12))
print(result(12, 13))
# Out:
# 12 is greater than 11
# 12 is equal to 12
# 12 is smaller than 13

# %%
result = lambda x: f"{x} pass with first class distinction"if x >=78\
                  else (f"{x} pass with first class" if x >=60\
                  else (f'{x} pass with second class' if x >=40\
                  else (f'{x} pass with third class' if x >=33\
                  else (f'{x} better luck next time'))))

# %%
print (result(92))
print (result(68))
print (result(45))
print (result(33))
print (result(25))
# Out:
# 92 pass with first class distinction
# 68 pass with first class
# 45 pass with second class
# 33 pass with third class
# 25 better luck next time

# %%
def func_sum(a, b):
  return a+b

# %%
def func_sum(a,b, c):
  return a+b+c

# %%
def func_sum(*arg):
  return arg

# %%
func_sum (12,3,5,6,7,8,9,3,4,5)
# Out:
# (12, 3, 5, 6, 7, 8, 9, 3, 4, 5)

# %%
def func_sum(*gp):
  sum=0
  for i in gp:
      sum+=i
      print(sum)

# %%
func_sum(30, 20, 50, 100, 200, 400)
# Out:
# 30
# 50
# 100
# 200
# 400
# 800

# %%
def func_sum(a, b, c, *args): # args (Non-Keyword Arguments)
  return a+b+c+(sum(args))

# %%
func_sum(12, 23, 34, 45, 67, 34, 23)
# Out:
# 238

# %%
def func_sum(*args, a, b, c): # *args has to be at the end otherwise it takes all the position and the fucntion neve reach the values beyond args
  return a+b+c+(sum(args))

# %%
func_sum(12, 23, 34, 45, 67, 34, 23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-92e3fcd3d93a> in <cell line: 1>()
# ----> 1 func_sum(12, 23, 34, 45, 67, 34, 23)
#
# TypeError: func_sum() missing 3 required keyword-only arguments: 'a', 'b', and 'c'

# %%
def func_sum(*args):
  return args

# %%
func_sum(12,23,34,45,56,67,78,89,90,101)
# Out:
# (12, 23, 34, 45, 56, 67, 78, 89, 90, 101)

# %%
func_sum([12,23,34],(45,56,67),78,89,90,101)
# Out:
# ([12, 23, 34], (45, 56, 67), 78, 89, 90, 101)

# %%
func_sum({12,23,34,45,56},67,78,89,90,101)
# Out:
# ({12, 23, 34, 45, 56}, 67, 78, 89, 90, 101)

# %%
func_sum({'a':12,'b':23,'c':34,'d':45,'e':56},67,78,89,90,101)
# Out:
# ({'a': 12, 'b': 23, 'c': 34, 'd': 45, 'e': 56}, 67, 78, 89, 90, 101)

# %%
def func_sum(*args):
  return args

# %%
func_sum('Apple','Book','Dog','House')
# Out:
# ('Apple', 'Book', 'Dog', 'House')

# %%
func_sum ({'a':'Apple', 'b': 'Banana', 'c':'Coconut'})
# Out:
# ({'a': 'Apple', 'b': 'Banana', 'c': 'Coconut'},)

# %%
func_sum ([1,2,3], [2,3,4], [4,5,6])
# Out:
# ([1, 2, 3], [2, 3, 4], [4, 5, 6])

# %%
func_sum (1, 2, 3, 'ABC', (3,6,9), [1,2,3], {'abc': 'ABCD'})
# Out:
# (1, 2, 3, 'ABC', (3, 6, 9), [1, 2, 3], {'abc': 'ABCD'})

# %%
func_sum ("This is crazy", "args takes anything")
# Out:
# ('This is crazy', 'args takes anything')

# %%
def func_sum(**kwargs):
  return kwargs

# %%
func_sum(fname="Govinda", mname ='P', lname ="Poudel")
# Out:
# {'fname': 'Govinda', 'mname': 'P', 'lname': 'Poudel'}

# %%
def EmployeeDetails(**kwargs):
  return kwargs

# %%
EmployeeDetails(name ="ABCD", position ="Data Scientist", age ="25", salary = 120000)
# Out:
# {'name': 'ABCD', 'position': 'Data Scientist', 'age': '25', 'salary': 120000}

# %%
def EmployeeDetails1(**args):
  return args

# %%
EmployeeDetails1(name ="ABCD", position ="Data Scientist", age ="25", salary = 120000)
# Out:
# {'name': 'ABCD', 'position': 'Data Scientist', 'age': '25', 'salary': 120000}

# %%
def EmployeeDetails(*args, **kwargs):
  return (args, kwargs)

# %%
EmployeeDetails(2,4, 6, fname="ABCD",lname="XYZ" )
# Out:
# ((2, 4, 6), {'fname': 'ABCD', 'lname': 'XYZ'})

# %%
def EmployeeDetails(**kwargs, *args):
  return (kwargs, args)
# Out:
#   File "<ipython-input-123-d09d2dbd6017>", line 1
#     def EmployeeDetails(**kwargs, *args):
#                                   ^
# SyntaxError: invalid syntax

# %%
def EmployeeDetails(*args, **kwargs):
  return (args, kwargs)

# %%
EmployeeDetails(2,4, 6, 7, 8,9,10,11, a= 'Apple')
# Out:
# ((2, 4, 6, 7, 8, 9, 10, 11), {'a': 'Apple'})

# %%
for i in range(10):
  str1=[]
  if i%2==0:
    str1.append(i)

# %%
def abc(*args, a, **kwargs):
    return (args, a, kwargs)

# %%
abc(2,4,5, 6, a="apple")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-eb9f281c78cf> in <cell line: 1>()
# ----> 1 abc(2,4,5, 6, a="apple")
#
# TypeError: abc() got multiple values for argument 'a'

# %%
def abc(*args, **kwargs, a):
    return (args, kwargs,a)
# Out:
#   File "<ipython-input-136-742405747e5a>", line 1
#     def abc(*args, **kwargs, a):
#                              ^
# SyntaxError: invalid syntax

# %%
abc(2,4,5, 6, a="apple", 5)
# Out:
#   File "<ipython-input-137-245c601dd2ff>", line 1
#     abc(2,4,5, 6, a="apple", 5)
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
def abc(a,*args,**kwargs):
    return (a, args, kwargs)

# %%
abc(2,True,5, 6, a="apple")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-5e2fc290d5fa> in <cell line: 1>()
# ----> 1 abc(2, True,5, 6, a="apple")
#
# TypeError: abc() got multiple values for argument 'a'
