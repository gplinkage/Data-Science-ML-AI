# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/DataScienceBootCamp/blob/main/Projects/California_Housing_Prices_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv("/content/housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
other_columns = [col for col in df.columns if col != 'median_house_value']

# %%
df = df[other_columns + ['median_house_value']]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0       322.0       126.0         8.3252        NEAR BAY            452600.0
# 1      2401.0      1138.0         8.3014        NEAR BAY            358500.0
# 2       496.0       177.0         7.2574        NEAR BAY            352100.0
# 3       558.0       219.0         5.6431        NEAR BAY            341300.0
# 4       565.0       259.0         3.8462        NEAR BAY            342200.0

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
df['total_bedrooms'].fillna(df['total_bedrooms'].median(), inplace=True)
# Out:
# <ipython-input-11-c9f555b11c0f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_bedrooms'].fillna(df['total_bedrooms'].median(), inplace=True)

# %%
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
from pandas.plotting import scatter_matrix
fig = plt.figure()
scatter_matrix(df,figsize =(25,25),alpha=0.9,diagonal="kde",marker="o");

# %%
df.hist(figsize=(25,25),bins=50)

# %%
hcorr = df.corr()
hcorr.style.background_gradient()
# Out:
# <ipython-input-16-6737370daf92>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hcorr = df.corr()
# <style type="text/css">
# #T_7a6bc_row0_col0, #T_7a6bc_row1_col1, #T_7a6bc_row2_col2, #T_7a6bc_row3_col3, #T_7a6bc_row4_col4, #T_7a6bc_row5_col5, #T_7a6bc_row6_col6, #T_7a6bc_row7_col7, #T_7a6bc_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7a6bc_row0_col1, #T_7a6bc_row1_col0, #T_7a6bc_row1_col8, #T_7a6bc_row2_col3, #T_7a6bc_row2_col4, #T_7a6bc_row2_col5, #T_7a6bc_row2_col6, #T_7a6bc_row2_col7, #T_7a6bc_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7a6bc_row0_col2 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_7a6bc_row0_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_7a6bc_row0_col4 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_7a6bc_row0_col5 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_7a6bc_row0_col6, #T_7a6bc_row1_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_7a6bc_row0_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_7a6bc_row0_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7a6bc_row1_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_7a6bc_row1_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_7a6bc_row1_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_7a6bc_row1_col6, #T_7a6bc_row7_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_7a6bc_row1_col7 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_7a6bc_row2_col0, #T_7a6bc_row5_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_7a6bc_row2_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_7a6bc_row2_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_7a6bc_row3_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_7a6bc_row3_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_7a6bc_row3_col4 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_7a6bc_row3_col5 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_7a6bc_row3_col6 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_7a6bc_row3_col7, #T_7a6bc_row8_col6 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_7a6bc_row3_col8, #T_7a6bc_row7_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_7a6bc_row4_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_7a6bc_row4_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_7a6bc_row4_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_7a6bc_row4_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_7a6bc_row4_col5, #T_7a6bc_row5_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_7a6bc_row4_col6 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_7a6bc_row4_col7, #T_7a6bc_row5_col8 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_7a6bc_row4_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_7a6bc_row5_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_7a6bc_row5_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_7a6bc_row5_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_7a6bc_row5_col6, #T_7a6bc_row6_col5 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_7a6bc_row5_col7 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_7a6bc_row6_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_7a6bc_row6_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_7a6bc_row6_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_7a6bc_row6_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_7a6bc_row6_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_7a6bc_row6_col7 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_7a6bc_row6_col8 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_7a6bc_row7_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_7a6bc_row7_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_7a6bc_row7_col3 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_7a6bc_row7_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_7a6bc_row7_col5 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_7a6bc_row7_col8 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_7a6bc_row8_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_7a6bc_row8_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_7a6bc_row8_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_7a6bc_row8_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_7a6bc_row8_col4 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_7a6bc_row8_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_7a6bc_row8_col7 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a6bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a6bc_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_7a6bc_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_7a6bc_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_7a6bc_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_7a6bc_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_7a6bc_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_7a6bc_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_7a6bc_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_7a6bc_level0_col8" class="col_heading level0 col8" >median_house_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a6bc_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_7a6bc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7a6bc_row0_col1" class="data row0 col1" >-0.924664</td>
#       <td id="T_7a6bc_row0_col2" class="data row0 col2" >-0.108197</td>
#       <td id="T_7a6bc_row0_col3" class="data row0 col3" >0.044568</td>
#       <td id="T_7a6bc_row0_col4" class="data row0 col4" >0.069120</td>
#       <td id="T_7a6bc_row0_col5" class="data row0 col5" >0.099773</td>
#       <td id="T_7a6bc_row0_col6" class="data row0 col6" >0.055310</td>
#       <td id="T_7a6bc_row0_col7" class="data row0 col7" >-0.015176</td>
#       <td id="T_7a6bc_row0_col8" class="data row0 col8" >-0.045967</td>
#     </tr>
#     <tr>
#       <th id="T_7a6bc_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_7a6bc_row1_col0" class="data row1 col0" >-0.924664</td>
#       <td id="T_7a6bc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7a6bc_row1_col2" class="data row1 col2" >0.011173</td>
#       <td id="T_7a6bc_row1_col3" class="data row1 col3" >-0.036100</td>
#       <td id="T_7a6bc_row1_col4" class="data row1 col4" >-0.066484</td>
#       <td id="T_7a6bc_row1_col5" class="data row1 col5" >-0.108785</td>
#       <td id="T_7a6bc_row1_col6" class="data row1 col6" >-0.071035</td>
#       <td id="T_7a6bc_row1_col7" class="data row1 col7" >-0.079809</td>
#       <td id="T_7a6bc_row1_col8" class="data row1 col8" >-0.144160</td>
#     </tr>
#     <tr>
#       <th id="T_7a6bc_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_7a6bc_row2_col0" class="data row2 col0" >-0.108197</td>
#       <td id="T_7a6bc_row2_col1" class="data row2 col1" >0.011173</td>
#       <td id="T_7a6bc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7a6bc_row2_col3" class="data row2 col3" >-0.361262</td>
#       <td id="T_7a6bc_row2_col4" class="data row2 col4" >-0.319026</td>
#       <td id="T_7a6bc_row2_col5" class="data row2 col5" >-0.296244</td>
#       <td id="T_7a6bc_row2_col6" class="data row2 col6" >-0.302916</td>
#       <td id="T_7a6bc_row2_col7" class="data row2 col7" >-0.119034</td>
#       <td id="T_7a6bc_row2_col8" class="data row2 col8" >0.105623</td>
#     </tr>
#     <tr>
#       <th id="T_7a6bc_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_7a6bc_row3_col0" class="data row3 col0" >0.044568</td>
#       <td id="T_7a6bc_row3_col1" class="data row3 col1" >-0.036100</td>
#       <td id="T_7a6bc_row3_col2" class="data row3 col2" >-0.361262</td>
#       <td id="T_7a6bc_row3_col

# %%
sns.set(context="paper",font="monospace")
housing_corr_matrix =  df.corr()
#set the matplotlib figure
fig, axe = plt.subplots(figsize=(12,8))
#Generate color palettes
cmap = sns.diverging_palette(220,10,center = "light", as_cmap=True)
#draw the heatmap
sns.heatmap(housing_corr_matrix,vmax=1,square =True, cmap=cmap,annot=True );
# Out:
# <ipython-input-17-ca57ef9c7b7b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   housing_corr_matrix =  df.corr()

# %%
def getOutliers(dataframe,column):
    column = "total_rooms"
    #housing[column].plot.box(figsize=(8,8))
    des = dataframe[column].describe()
    desPairs = {"count":0,"mean":1,"std":2,"min":3,"25":4,"50":5,"75":6,"max":7}
    Q1 = des[desPairs['25']]
    Q3 = des[desPairs['75']]
    IQR = Q3-Q1
    lowerBound = Q1-1.5*IQR
    upperBound = Q3+1.5*IQR
    print("(IQR = {})Outlier are anything outside this range: ({},{})".format(IQR,lowerBound,upperBound))
    #b = df[(df['a'] > 1) & (df['a'] < 5)]
    data = dataframe[(dataframe [column] < lowerBound) | (dataframe [column] > upperBound)]

    print("Outliers out of total = {} are \n {}".format(df[column].size,len(data[column])))
    #remove the outliers from the dataframe
    outlierRemoved = df[~df[column].isin(data[column])]
    return outlierRemoved

# %%
df_outliersRemoved = getOutliers(df,"total_rooms")
# Out:
# (IQR = 1700.25)Outlier are anything outside this range: (-1102.625,5698.375)
# Outliers out of total = 20640 are
#  1287

# %%
total_bedroms = df[df["total_bedrooms"].notnull()]["total_bedrooms"]
total_bedroms.hist(figsize=(12,8),bins=50)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
print(df["ocean_proximity"].value_counts())
df["ocean_proximity"] = labelEncoder.fit_transform(df["ocean_proximity"])
df["ocean_proximity"].value_counts()
df.describe()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       536.838857   1425.476744    499.539680       3.870671
# std        419.391878   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        643.250000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        ocean_proximity  median_house_value
# count     20640.000000        20640.000000
# mean          1.165843       206855.816909
# std           1.420662       115395.615874
# min           0.000000        14999.000000
# 25%           0.000000       119600.000000
# 50%           1.000000       179700.000000
# 75%           1.000000       264725.000000
# max           4.000000       500001.000000

# %%
housing_ind = df.drop("median_house_value",axis=1)
print(housing_ind.head())
housing_dep = df["median_house_value"]
print("Medain Housing Values")
print(housing_dep.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  ocean_proximity
# 0       322.0       126.0         8.3252                3
# 1      2401.0      1138.0         8.3014                3
# 2       496.0       177.0         7.2574                3
# 3       558.0       219.0         5.6431                3
# 4       565.0       259.0         3.8462                3
# Medain Housing Values
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(housing_ind,housing_dep,test_size=0.2,random_state=42)

# %%
print("X_train shape {} and size {}".format(X_train.shape,X_train.size))
print("X_test shape {} and size {}".format(X_test.shape,X_test.size))
print("y_train shape {} and size {}".format(y_train.shape,y_train.size))
print("y_test shape {} and size {}".format(y_test.shape,y_test.size))
# Out:
# X_train shape (16512, 9) and size 148608
# X_test shape (4128, 9) and size 37152
# y_train shape (16512,) and size 16512
# y_test shape (4128,) and size 4128

# %%
from sklearn.preprocessing import StandardScaler
independent_scaler = StandardScaler()
X_train = independent_scaler.fit_transform(X_train)
X_test = independent_scaler.transform(X_test)
print(X_train[0:5,:])
print("test data")
print(X_test[0:5,:])
# Out:
# [[ 1.27258656 -1.3728112   0.34849025  0.22256942  0.21122752  0.76827628
#    0.32290591 -0.326196    2.00593172]
#  [ 0.70916212 -0.87669601  1.61811813  0.34029326  0.59309419 -0.09890135
#    0.6720272  -0.03584338  2.00593172]
#  [-0.44760309 -0.46014647 -1.95271028 -0.34259695 -0.49522582 -0.44981806
#   -0.43046109  0.14470145  2.00593172]
#  [ 1.23269811 -1.38217186  0.58654547 -0.56148971 -0.40930582 -0.00743434
#   -0.38058662 -1.01786438  2.00593172]
#  [-0.10855122  0.5320839   1.14200767 -0.11956547 -0.25655915 -0.48587717
#   -0.31496232 -0.17148831 -0.1124266 ]]
# test data
# [[ 0.28534728  0.1951     -0.28632369 -0.52286157 -0.24701249 -0.03030109
#   -0.37008673 -1.15508475 -0.1124266 ]
#  [ 0.06097472 -0.23549054  0.11043502  0.13841528 -0.24701249  0.12185077
#    0.220532   -0.70865905 -0.1124266 ]
#  [-1.42487026  1.00947776  1.85617335  0.54630997 -0.24701249 -0.10241931
#    1.21539643 -0.21040155  1.29981228]
#  [ 0.42994293 -0.63799909 -0.92113763  0.18808002 -0.24701249  0.24497944
#   -0.01309052  0.97511311 -0.81854604]
#  [-1.17058135  0.45719859  0.42784199 -0.13382109 -0.24701249 -0.31965346
#   -0.18896365 -0.08179356  2.00593172]]

# %%
from sklearn.linear_model import LinearRegression
linearRegModel = LinearRegression()
#fit the model to the training data (learn the coefficients)
linearRegModel.fit(X_train,y_train)
#print the intercept and coefficients
print("Intercept is "+str(linearRegModel.intercept_))
print("coefficients  is "+str(linearRegModel.coef_))
# Out:
# Intercept is 207194.69373788778
# coefficients  is [-85854.94724101 -90946.06271148  14924.30655143 -17693.23405277
#   48767.60670995 -43884.16852449  17601.31495096  77144.10164179
#    -451.52015229]

# %%
#predict on the test data
y_pred = linearRegModel.predict(X_test)

# %%
print(len(y_pred))
print(len(y_test))
print(y_pred[0:5])
print(y_test[0:5])
# Out:
# 4128
# 4128
# [ 63642.8756283  154445.82484211 252777.76132135 263796.8643552
#  266307.35634572]
# 20046     47700.0
# 3024      45800.0
# 15663    500001.0
# 20484    218600.0
# 9814     278000.0
# Name: median_house_value, dtype: float64

# %%
test = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind='reg',);

# %%
from sklearn.tree import DecisionTreeRegressor
dtReg = DecisionTreeRegressor(max_depth=9)
dtReg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=9)

# %%
dtReg_y_pred = dtReg.predict(X_test)
dtReg_y_pred
# Out:
# array([ 60503.2556391 ,  75919.52054795, 478283.56097561, ...,
#        488611.25      ,  75919.52054795, 211563.96963563])

# %%
test = pd.DataFrame({'Predicted':dtReg_y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind="reg")
